# %%
import numpy as np #biblioteca numpy
#Fazer cálculos matematicos
from sklearn.model_selection import train_test_split # importa da biblioteca sklerarn.model a biblioteca train test split
#essa biblioteca train test split serve para dividir os dados
#teste treino
from sklearn.tree import DecisionTreeClassifier # vai importar  algaritimo da arvore de decição
from sklearn import tree #importando a bibliotca para plotar a arvore
import matplotlib.pyplot as plt #importa  biblioteca matplotlib
import seaborn as sns # importa a biblioteca seaborn
from sklearn.metrics import accuracy_score #métrica de ácuracia do algoritimo
from sklearn.metrics import precision_score #métrica de precissão de algoritimo
from sklearn.metrics import recall_score #métrica de recall de algoritmo
from sklearn.metrics import f1_score #métrica de F1 score
from sklearn.metrics import confusion_matrix # importa matiz de confusão

# %%
#pip install scikit-learn

# %%
#Criando o conjunto de dados
notas = np.array([8,6,5,9,4,3,7,2,1,5,6,9,8])
classes = np.array(['bom', 'ruim', 'ruim', 'bom', 'pessimo', 
                    'pessimo', 'bom', 'pessimo',
                    'pessimo', 'ruim', 'ruim', 'bom', 'bom'])

# %%
#dividir dados em teste e treino
notas_treino, notas_teste, classes_treino,classes_teste = train_test_split(notas.reshape(-1,1),
                                                                            classes.reshape(-1,1), test_size=0.2, 
                                                                            random_state=42)

# %%
modelo = DecisionTreeClassifier() #Criação do modelo de árvore de decisão
modelo.fit(notas_treino,classes_treino) # treinamento do modelo de árvore de decisão
# Out:
# DecisionTreeClassifier()

# %%
previsoes = modelo.predict(notas_teste) #Dentro do modelo predict é colocado as previssoe
previsoes
# Out:
# array(['bom', 'ruim', 'bom'], dtype='<U7')

# %%
notas_teste
# Out:
# array([[9],
#        [5],
#        [8]])

# %%
#testes de nota individual
nota=np.array([4]).reshape(-1,1)
resultado = modelo.predict(nota)
resultado
# Out:
# array(['pessimo'], dtype='<U7')

# %%
fig = plt.figure(figsize=(10,8)) #criando uma figura do tamamho 10 X 8
#tree plot plota a arvore de decião
# modelo é o modelo criado do algoritmo de aprendizado supervisionado
tree.plot_tree(modelo,feature_names=notas.tolist(), class_names=classes.tolist(),filled=True)
plt.title('Arvore de decisão para classificar uma bebida \n'
          'de acordo com a nota', fontsize=18)
plt.show()

# %%
#plota box plot com a biblioteca seaborn
#x é o eixo que indica as classes: boa, ruim ou péssimas
#y indica as notas
plt.figure(figsize=(10,8))

plt.title('Box Plot das notas de classes das bebidas')

sns.boxplot(x = classes, y = notas)  #sns > boxplot feito com a biblioteca Seaborn, ao ibes da matplotlib
plt.grid()

# %%
#Grafico de barras
sns.barplot(y=notas, x = classes) #plotando o grafico de barras (sns é a biblioteca seaborn)
sns.set(font_scale=1) #escala do tamanho da fonte dos textos

plt.title('Notas de bebidas', fontsize=20)
plt.ylabel('Classificação', fontsize=16)
plt.ylabel('Notas', fontsize=16)
# Out:
# Text(0, 0.5, 'Notas')

# %%
#métrica do sistema --> Importada de sklearn.metrics --> accuracy_score
acuracy=accuracy_score(classes_teste, previsoes)
acuracy #método de mostrar o resultado é escrevendo o nome da variavel e apertando em ok
# Out:
# 1.0

# %%
#Métrica do sistema --> Importada de Sklearn --> precision_score
precissao = precision_score(classes_teste, previsoes, pos_label='bom')
precissao
# Out:
# 1.0

# %%
#Métrica do Sistema --> Importada de Sklearn --> recall_score
recall = recall_score(classes_teste, previsoes, pos_label='ruim')
recall
# Out:
# 1.0

# %%
#Métrica do Sistema --> Importada de Sklearn.metrics --> F1_score
fiscore = f1_score(classes_teste, previsoes, pos_label='bom')
fiscore
# Out:
# 1.0

# %%
nota=np.array([9.7]).reshape(-1,1)
resultado=modelo.predict(nota)
resultado
# Out:
# array(['bom'], dtype='<U7')
